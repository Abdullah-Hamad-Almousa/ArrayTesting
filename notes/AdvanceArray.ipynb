# %%
import numpy as np

# %%
a = np.array([1, 2, 3, 4])

b = np.array([1, 2, 1, 4])

diff = a - b

sum_square = np.sum(diff ** 2)

mse = np.sum(sum_square) / len(a)

mse

# %%
data = np.array([10, 20, 30, 40, 50])

indexed_data = data[[1, 3]]

mean_value = np.mean(indexed_data)

# %%
a = np.array([1, 2, 3])
b = np.array([4, 5, 6])
c = np.array([a, b])
c

# %%
numbers = np.array([2.718, 7.389, 20.085])

log_values = np.log(numbers)

exp_values = np.exp(log_values)

# %%
seq1 = np.arange(1, 10)
seq2 = np.arange(11, 20)
matrix_a = seq1.reshape(3, 3)
matrix_b = seq2.reshape(3, 3)
matrix_result = matrix_a @ matrix_b
matrix_result
