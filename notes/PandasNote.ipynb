# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
num = range(1, 100, 7)
pd.Series(num)
# Out:
# 0      1
# 1      8
# 2     15
# 3     22
# 4     29
# 5     36
# 6     43
# 7     50
# 8     57
# 9     64
# 10    71
# 11    78
# 12    85
# 13    92
# 14    99
# dtype: int64

# %%
string = "Hi", "How", "Welcome", "Anything", "to", "Write"
pd.Series(string)
# Out:
# 0          Hi
# 1         How
# 2     Welcome
# 3    Anything
# 4          to
# 5       Write
# dtype: object

# %%
st = pd.Series([373, 'Saudi Arabia', 37.3, 'Riyadh', -73.3])
st
# Out:
# 0             373
# 1    Saudi Arabia
# 2            37.3
# 3          Riyadh
# 4           -73.3
# dtype: object

# %%
obSt = pd.Series([[st], [num], [string], 37.3, 'Riyadh', -73.3])
obSt
# Out:
# 0           [[373, Saudi Arabia, 37.3, Riyadh, -73.3]]
# 1    [(1, 8, 15, 22, 29, 36, 43, 50, 57, 64, 71, 78...
# 2            [(Hi, How, Welcome, Anything, to, Write)]
# 3                                                 37.3
# 4                                               Riyadh
# 5                                                -73.3
# dtype: object

# %%
marks = [60, 70, 80, 90, 100]

subject = ["Math", "Science", "Programming", "English", "Religion"]

pd.Series(marks, index=subject)
# Out:
# Math            60
# Science         70
# Programming     80
# English         90
# Religion       100
# dtype: int64

# %%
data = {"Math": 60, "Science": 70, "Programming": 90, "English": 80, "Religion": 100}
pd.Series(data)
# Out:
# Math            60
# Science         70
# Programming     90
# English         80
# Religion       100
# dtype: int64

# %%
subject = ["Math", "Science", "Python", "English", "Religion"]
dataSubject = pd.Series(data, index=subject)
dataSubject
# Out:
# Math         60.0
# Science      70.0
# Python        NaN
# English      80.0
# Religion    100.0
# dtype: float64

# %%
dataSubject.isnull()
# Out:
# Math        False
# Science     False
# Python       True
# English     False
# Religion    False
# dtype: bool

# %%
dataSubject.notnull()
# Out:
# Math         True
# Science      True
# Python      False
# English      True
# Religion     True
# dtype: bool

# %%
dataSubject[dataSubject > 75]
# Out:
# English      80.0
# Religion    100.0
# dtype: float64

# %%
dataSubject["Python"] = 68
dataSubject
# Out:
# Math         60.0
# Science      70.0
# Python       68.0
# English      80.0
# Religion    100.0
# dtype: float64

# %%
dataSubject.Science == 20
# Out:
# np.False_

# %%
values = pd.Series([23, 45, np.nan, 41, 23, 34, 55, np.nan, 34, 20])
values
# Out:
# 0    23.0
# 1    45.0
# 2     NaN
# 3    41.0
# 4    23.0
# 5    34.0
# 6    55.0
# 7     NaN
# 8    34.0
# 9    20.0
# dtype: float64

# %%
values.sort_values(ascending=False)
# Out:
# 6    55.0
# 1    45.0
# 3    41.0
# 5    34.0
# 8    34.0
# 0    23.0
# 4    23.0
# 9    20.0
# 2     NaN
# 7     NaN
# dtype: float64

# %%
string_values = pd.Series(["H", "A", "Z", "A", "T", "I"])
string_values
# Out:
# 0    H
# 1    A
# 2    Z
# 3    A
# 4    T
# 5    I
# dtype: object

# %%
string_values.sort_values(ascending=True)
# Out:
# 1    A
# 3    A
# 0    H
# 5    I
# 4    T
# 2    Z
# dtype: object

# %%
dataSubject.rank(ascending=True, pct=False)
# Out:
# Math        1.0
# Science     3.0
# Python      2.0
# English     4.0
# Religion    5.0
# dtype: float64

# %%
data = { 'Subject': ['Maths', 'Science', 'Python', 'English', 'Religion', 'Java'],
         'Marks': (78, 89, 79, 65, 77, 99),
         'CGPA': [3.5, 4, 5, 2.5, 3.5, 5]}

df = pd.DataFrame(data)
df
# Out:
#     Subject  Marks  CGPA
# 0     Maths     78   3.5
# 1   Science     89   4.0
# 2    Python     79   5.0
# 3   English     65   2.5
# 4  Religion     77   3.5
# 5      Java     99   5.0

# %%
Subject = pd.Series(['Maths', 'Science', 'Python', 'English', 'Religion', 'Java'])
Marks = pd.Series([78, 89, 79, 65, 77, 99])
CGPA = pd.Series([3.5, 4, 5, 2.5, 3.5, 5])

# %%
GatherData = pd.DataFrame([Subject, Marks, CGPA], index=['Subject', 'Marks', 'CGPA'])
GatherData
# Out:
#              0        1       2        3         4     5
# Subject  Maths  Science  Python  English  Religion  Java
# Marks       78       89      79       65        77    99
# CGPA       3.5      4.0     5.0      2.5       3.5   5.0

# %% [markdown]
# Use T to Vertical dataframe

# %%
GatherData = pd.DataFrame([Subject, Marks, CGPA], index=['Subject', 'Marks', 'CGPA']).T
GatherData
# Out:
#     Subject Marks CGPA
# 0     Maths    78  3.5
# 1   Science    89  4.0
# 2    Python    79  5.0
# 3   English    65  2.5
# 4  Religion    77  3.5
# 5      Java    99  5.0

# %%
data = pd.read_csv("data.csv")
data.head(3)
# Out:
#    person_age person_gender person_education  person_income  person_emp_exp  \
# 0        22.0        female           Master        71948.0               0
# 1        21.0        female      High School        12282.0               0
# 2        25.0        female      High School        12438.0               3
#
#   person_home_ownership  loan_amnt loan_intent  loan_int_rate  \
# 0                  RENT    35000.0    PERSONAL          16.02
# 1                   OWN     1000.0   EDUCATION          11.14
# 2              MORTGAGE     5500.0     MEDICAL          12.87
#
#    loan_percent_income  cb_person_cred_hist_length  credit_score  \
# 0                 0.49                         3.0           561
# 1                 0.08                         2.0           504
# 2                 0.44                         3.0           635
#
#   previous_loan_defaults_on_file  loan_status
# 0                             No            1
# 1                            Yes            0
# 2                             No            1

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.shape
# Out:
# (45000, 14)

# %%
data.isnull().sum()
# Out:
# person_age                        0
# person_gender                     0
# person_education                  0
# person_income                     0
# person_emp_exp                    0
# person_home_ownership             0
# loan_amnt                         0
# loan_intent                       0
# loan_int_rate                     0
# loan_percent_income               0
# cb_person_cred_hist_length        0
# credit_score                      0
# previous_loan_defaults_on_file    0
# loan_status                       0
# dtype: int64

# %% [markdown]
# No null in the data

# %%
data.describe()
# Out:
#          person_age  person_income  person_emp_exp     loan_amnt  \
# count  45000.000000   4.500000e+04    45000.000000  45000.000000
# mean      27.764178   8.031905e+04        5.410333   9583.157556
# std        6.045108   8.042250e+04        6.063532   6314.886691
# min       20.000000   8.000000e+03        0.000000    500.000000
# 25%       24.000000   4.720400e+04        1.000000   5000.000000
# 50%       26.000000   6.704800e+04        4.000000   8000.000000
# 75%       30.000000   9.578925e+04        8.000000  12237.250000
# max      144.000000   7.200766e+06      125.000000  35000.000000
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# count   45000.000000         45000.000000                45000.000000
# mean       11.006606             0.139725                    5.867489
# std         2.978808             0.087212                    3.879702
# min         5.420000             0.000000                    2.000000
# 25%         8.590000             0.070000                    3.000000
# 50%        11.010000             0.120000                    4.000000
# 75%        12.990000             0.190000                    8.000000
# max        20.000000             0.660000                   30.000000
#
#        credit_score   loan_status
# count  45000.000000  45000.000000
# mean     632.608756      0.222222
# std       50.435865      0.415744
# min      390.000000      0.000000
# 25%      601.000000      0.000000
# 50%      640.000000      0.000000
# 75%      670.000000      0.000000
# max      850.000000      1.000000

# %%
data.tail(3)
# Out:
#        person_age person_gender person_education  person_income  \
# 44997        33.0          male        Associate        56942.0
# 44998        29.0          male         Bachelor        33164.0
# 44999        24.0          male      High School        51609.0
#
#        person_emp_exp person_home_ownership  loan_amnt        loan_intent  \
# 44997               7                  RENT     2771.0  DEBTCONSOLIDATION
# 44998               4                  RENT    12000.0          EDUCATION
# 44999               1                  RENT     6665.0  DEBTCONSOLIDATION
#
#        loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# 44997          10.02                 0.05                        10.0
# 44998          13.23                 0.36                         6.0
# 44999          17.05                 0.13                         3.0
#
#        credit_score previous_loan_defaults_on_file  loan_status
# 44997           668                             No            1
# 44998           604                             No            1
# 44999           628                             No            1

# %%
data.dtypes
# Out:
# person_age                        float64
# person_gender                      object
# person_education                   object
# person_income                     float64
# person_emp_exp                      int64
# person_home_ownership              object
# loan_amnt                         float64
# loan_intent                        object
# loan_int_rate                     float64
# loan_percent_income               float64
# cb_person_cred_hist_length        float64
# credit_score                        int64
# previous_loan_defaults_on_file     object
# loan_status                         int64
# dtype: object

# %% [markdown]
# data.info() can give you shape number of columns and names null data type

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45000 entries, 0 to 44999
# Data columns (total 14 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   person_age                      45000 non-null  float64
#  1   person_gender                   45000 non-null  object
#  2   person_education                45000 non-null  object
#  3   person_income                   45000 non-null  float64
#  4   person_emp_exp                  45000 non-null  int64
#  5   person_home_ownership           45000 non-null  object
#  6   loan_amnt                       45000 non-null  float64
#  7   loan_intent                     45000 non-null  object
#  8   loan_int_rate                   45000 non-null  float64
#  9   loan_percent_income             45000 non-null  float64
#  10  cb_person_cred_hist_length      45000 non-null  float64
#  11  credit_score                    45000 non-null  int64
#  12  previous_loan_defaults_on_file  45000 non-null  object
#  13  loan_status                     45000 non-null  int64
# dtypes: float64(6), int64(3), object(5)
# memory usage: 4.8+ MB

# %% [markdown]
# # New Section

# %%
df = pd.read_csv("bmi.csv")
df.head(3)
# Out:
#    Gender  Height  Weight  Index
# 0    Male     174      96      4
# 1    Male     189      87      2
# 2  Female     185     110      4

# %%
df["Height"] = df["Height"]*0.01

# %%
df["BMI"] = df["Weight"] / df["Height"]**2
df.head(3)
# Out:
#    Gender  Height  Weight  Index        BMI
# 0    Male    1.74      96      4  31.708284
# 1    Male    1.89      87      2  24.355421
# 2  Female    1.85     110      4  32.140248

# %%
df = df.rename(columns={"Gender": "Male"})

genderMap = {'Male': 1, 'Female': 0}
df["Male"] = df["Male"].map(genderMap)
df.head(3)
# Out:
#    Male  Height  Weight  Index        BMI
# 0     1    1.74      96      4  31.708284
# 1     1    1.89      87      2  24.355421
# 2     0    1.85     110      4  32.140248

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Male    500 non-null    int64
#  1   Height  500 non-null    float64
#  2   Weight  500 non-null    int64
#  3   Index   500 non-null    int64
#  4   BMI     500 non-null    float64
# dtypes: float64(2), int64(3)
# memory usage: 19.7 KB

# %%
df.drop("Index", axis=1, inplace=True)
df.head(3)
# Out:
#    Male  Height  Weight        BMI
# 0     1    1.74      96  31.708284
# 1     1    1.89      87  24.355421
# 2     0    1.85     110  32.140248

# %%
dfCopy = df.copy()
dfCopy.loc[501] = [1, 1.82, 125, 37.736988]
df = dfCopy
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 501 entries, 0 to 501
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Male    501 non-null    float64
#  1   Height  501 non-null    float64
#  2   Weight  501 non-null    float64
#  3   BMI     501 non-null    float64
# dtypes: float64(4)
# memory usage: 19.6 KB

# %%
df.iloc[500]
# Out:
# Male        1.000000
# Height      1.820000
# Weight    125.000000
# BMI        37.736988
# Name: 501, dtype: float64

# %%
df.iloc[[3, 7, 10]]
# Out:
#     Male  Height  Weight        BMI
# 3    0.0    1.95   104.0  27.350427
# 7    1.0    1.54   111.0  46.803846
# 10   1.0    1.95    81.0  21.301775

# %%
df[df['BMI'] > 70]
# Out:
#      Male  Height  Weight        BMI
# 49    1.0    1.40   152.0  77.551020
# 61    0.0    1.41   143.0  71.927971
# 111   0.0    1.46   157.0  73.653594
# 147   0.0    1.40   146.0  74.489796
# 204   1.0    1.45   160.0  76.099881
# 211   1.0    1.48   155.0  70.763331
# 247   0.0    1.42   159.0  78.853402
# 251   1.0    1.40   143.0  72.959184
# 421   1.0    1.40   146.0  74.489796
# 442   1.0    1.43   149.0  72.864199

# %%
df[df['BMI'] < 15]
# Out:
#      Male  Height  Weight        BMI
# 60    0.0    1.91    54.0  14.802226
# 62    1.0    1.93    54.0  14.497033
# 85    1.0    1.98    50.0  12.753801
# 99    0.0    1.90    50.0  13.850416
# 150   0.0    1.96    50.0  13.015410
# 244   0.0    1.83    50.0  14.930276
# 354   1.0    1.90    50.0  13.850416
# 492   0.0    1.98    50.0  12.753801

# %%
df = df.drop(244)
df[df['BMI'] < 15]
# Out:
#      Male  Height  Weight        BMI
# 60    0.0    1.91    54.0  14.802226
# 62    1.0    1.93    54.0  14.497033
# 85    1.0    1.98    50.0  12.753801
# 99    0.0    1.90    50.0  13.850416
# 150   0.0    1.96    50.0  13.015410
# 354   1.0    1.90    50.0  13.850416
# 492   0.0    1.98    50.0  12.753801

# %%
df.iloc[13:17]
# Out:
#     Male  Height  Weight        BMI
# 13   1.0    1.55    51.0  21.227888
# 14   1.0    1.91    79.0  21.655108
# 15   0.0    1.53   107.0  45.708915
# 16   0.0    1.57   110.0  44.626557

# %%
df.iloc[:, -2]
# Out:
# 0       96.0
# 1       87.0
# 2      110.0
# 3      104.0
# 4       61.0
#        ...
# 496    121.0
# 497    136.0
# 498     95.0
# 499    131.0
# 501    125.0
# Name: Weight, Length: 500, dtype: float64

# %%
df.iloc[:, 0:2]
# Out:
#      Male  Height
# 0     1.0    1.74
# 1     1.0    1.89
# 2     0.0    1.85
# 3     0.0    1.95
# 4     1.0    1.49
# ..    ...     ...
# 496   0.0    1.84
# 497   0.0    1.41
# 498   1.0    1.50
# 499   1.0    1.73
# 501   1.0    1.82
#
# [500 rows x 2 columns]

# %%
df.iloc[3:13, 1:3]
# Out:
#     Height  Weight
# 3     1.95   104.0
# 4     1.49    61.0
# 5     1.89   104.0
# 6     1.47    92.0
# 7     1.54   111.0
# 8     1.74    90.0
# 9     1.69   103.0
# 10    1.95    81.0
# 11    1.59    80.0
# 12    1.92   101.0

# %%
df.loc[7:17, ["Weight", "BMI"]]
# Out:
#     Weight        BMI
# 7    111.0  46.803846
# 8     90.0  29.726516
# 9    103.0  36.063163
# 10    81.0  21.301775
# 11    80.0  31.644318
# 12   101.0  27.398003
# 13    51.0  21.227888
# 14    79.0  21.655108
# 15   107.0  45.708915
# 16   110.0  44.626557
# 17   129.0  65.816327

# %%
df.BMI
# Out:
# 0      31.708284
# 1      24.355421
# 2      32.140248
# 3      27.350427
# 4      27.476240
#          ...
# 496    35.739603
# 497    68.407022
# 498    42.222222
# 499    43.770256
# 501    37.736988
# Name: BMI, Length: 500, dtype: float64

# %%
df["BMI"]
# Out:
# 0      31.708284
# 1      24.355421
# 2      32.140248
# 3      27.350427
# 4      27.476240
#          ...
# 496    35.739603
# 497    68.407022
# 498    42.222222
# 499    43.770256
# 501    37.736988
# Name: BMI, Length: 500, dtype: float64

# %%
df[["BMI", "Male"]]
# Out:
#            BMI  Male
# 0    31.708284   1.0
# 1    24.355421   1.0
# 2    32.140248   0.0
# 3    27.350427   0.0
# 4    27.476240   1.0
# ..         ...   ...
# 496  35.739603   0.0
# 497  68.407022   0.0
# 498  42.222222   1.0
# 499  43.770256   1.0
# 501  37.736988   1.0
#
# [500 rows x 2 columns]

# %%
df.sort_values("BMI", ascending=False)
# Out:
#      Male  Height  Weight        BMI
# 247   0.0    1.42   159.0  78.853402
# 49    1.0    1.40   152.0  77.551020
# 204   1.0    1.45   160.0  76.099881
# 421   1.0    1.40   146.0  74.489796
# 147   0.0    1.40   146.0  74.489796
# ..    ...     ...     ...        ...
# 99    0.0    1.90    50.0  13.850416
# 354   1.0    1.90    50.0  13.850416
# 150   0.0    1.96    50.0  13.015410
# 85    1.0    1.98    50.0  12.753801
# 492   0.0    1.98    50.0  12.753801
#
# [500 rows x 4 columns]

# %%
plt.scatter(x="BMI", y="Height", data=df)

# %%
df.query('BMI < 30 & Height < 1.42')
# Out:
#      Male  Height  Weight        BMI
# 151   1.0     1.4    52.0  26.530612

# %%
df = df.drop(151)
